# %%
# Epoch 1/30 | RMSE: 0.108567 | time: 1183.78s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.10857.pt
#
# Epoch 2/30 | RMSE: 0.055748 | time: 1183.70s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.05575.pt
#
# Epoch 3/30 | RMSE: 0.051175 | time: 1183.63s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.05118.pt
#
# Epoch 4/30 | RMSE: 0.043748 | time: 1183.47s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.04375.pt
#
# Epoch 5/30 | RMSE: 0.041702 | time: 1183.48s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.04170.pt
#
# Epoch 6/30 | RMSE: 0.040349 | time: 1186.46s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.04035.pt
#
# Epoch 7/30 | RMSE: 0.037023 | time: 1183.69s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03702.pt
#
# Epoch 8/30 | RMSE: 0.036027 | time: 1184.12s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03603.pt
#
# Epoch 9/30 | RMSE: 0.036420 | time: 1183.61s
#
# Epoch 10/30 | RMSE: 0.033312 | time: 1183.54s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03331.pt
#
# Epoch 11/30 | RMSE: 0.031843 | time: 1183.52s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03184.pt
#
# Epoch 12/30 | RMSE: 0.031620 | time: 1183.59s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03162.pt
#
# Epoch 13/30 | RMSE: 0.031273 | time: 1183.62s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03127.pt
#
# Epoch 14/30 | RMSE: 0.030836 | time: 1183.44s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03084.pt
#
# Epoch 15/30 | RMSE: 0.030524 | time: 1183.51s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03052.pt
#
# Epoch 16/30 | RMSE: 0.030129 | time: 1183.53s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.03013.pt
#
# Epoch 17/30 | RMSE: 0.029973 | time: 1183.65s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02997.pt
#
# Epoch 18/30 | RMSE: 0.029660 | time: 1183.64s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02966.pt
#
# Epoch 19/30 | RMSE: 0.029354 | time: 1183.59s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02935.pt
#
# Epoch 20/30 | RMSE: 0.029213 | time: 1183.60s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02921.pt
#
# Epoch 21/30 | RMSE: 0.028597 | time: 1183.56s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02860.pt
#
# Epoch 22/30 | RMSE: 0.028489 | time: 1183.65s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02849.pt
#
# Epoch 23/30 | RMSE: 0.028353 | time: 1183.51s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02835.pt
#
# Epoch 24/30 | RMSE: 0.028264 | time: 1182.39s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02826.pt
#
# Epoch 25/30 | RMSE: 0.028067 | time: 1182.70s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02807.pt
#
# Epoch 26/30 | RMSE: 0.028111 | time: 1182.57s
#
# Epoch 27/30 | RMSE: 0.027801 | time: 1182.57s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02780.pt
#
# Epoch 28/30 | RMSE: 0.027767 | time: 1182.69s
# Saved best model to result/finetune_radiomap3d_20260113_030327/model_0.02777.pt
#
# Epoch 29/30 | RMSE: 0.027999 | time: 1182.89s
#
# Epoch 30/30 | RMSE: 0.027808 | time: 1182.73s
# Best RMSE: 0.027767
